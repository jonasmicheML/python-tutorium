# %% [markdown]
# # Introduction to Data Science

# %%
import pandas as pd
import numpy as np

# %%
movie_df = pd.read_csv("data/imdb_movies_shows.csv")

# %%
movie_df.head(10)
# Out:
#                                  title   type  release_year age_certification  \
# 0  Five Came Back: The Reference Films   SHOW          1945             TV-MA
# 1                          Taxi Driver  MOVIE          1976                 R
# 2      Monty Python and the Holy Grail  MOVIE          1975                PG
# 3                        Life of Brian  MOVIE          1979                 R
# 4                         The Exorcist  MOVIE          1973                 R
# 5         Monty Python's Flying Circus   SHOW          1969             TV-14
# 6                          Dirty Harry  MOVIE          1971                 R
# 7                         My Fair Lady  MOVIE          1964                 G
# 8                      The Blue Lagoon  MOVIE          1980                 R
# 9                     Bonnie and Clyde  MOVIE          1967                 R
#
#    runtime                                   genres production_countries  \
# ...

# %% [markdown]
# List all columns in the dataset.

# %%
movie_df.columns
# Out:
# Index(['title', 'type', 'release_year', 'age_certification', 'runtime',
#        'genres', 'production_countries', 'seasons', 'imdb_id', 'imdb_score',
#        'imdb_votes'],
#       dtype='object')

# %%
titles = movie_df["title"]

print(type(titles))

titles
# Out:
# <class 'pandas.core.series.Series'>
# 0       Five Came Back: The Reference Films
# 1                               Taxi Driver
# 2           Monty Python and the Holy Grail
# 3                             Life of Brian
# 4                              The Exorcist
#                        ...
# 5801                              Fine Wine
# 5802                         Edis Starlight
# 5803                                  Clash
# 5804                         Shadow Parties
# 5805     Mighty Little Bheem: Kite Festival
# Name: title, Length: 5806, dtype: object

# %% [markdown]
# Convert the titles series to a list.

# %%
titles_list = list(titles)
titles_list
# Out:
# ['Five Came Back: The Reference Films',
#  'Taxi Driver',
#  'Monty Python and the Holy Grail',
#  'Life of Brian',
#  'The Exorcist',
#  "Monty Python's Flying Circus",
#  'Dirty Harry',
#  'My Fair Lady',
#  'The Blue Lagoon',
#  'Bonnie and Clyde',
#  'The Professionals',
#  'The Guns of Navarone',
#  'Lupin the Third: The Castle of Cagliostro',
#  'Richard Pryor: Live in Concert',
#  'The Long Riders',
#  'White Christmas',
#  'Cairo Station',
#  'The Queen',
#  'Hitler: A Career',
#  'FTA',
#  'Saladin the Victorious',
#  'Singapore',
#  'Dark Waters',
#  'Alexandria… Why?',
#  'Raya and Sakina',
#  'No Longer Kids',
#  'Amrapali',
#  'Dostana',
#  'The Blazing Sun',
#  "Monty Python's Fliegender Zirkus",
#  'The Return of the Prodigal Son',
#  'Prince',
#  'Lock Your Girls In',
#  "The Witness Who Didn't See Anything",
#  'The School of Mischief',
#  'Manoranjan',
#  'Beirut, Oh Beirut',
#  'We Are All for the Fatherland',
#  'Whispers',
#  'Lal Patthar',
#  'Ujala',
# ...

# %% [markdown]
# Get basic information about the data set.

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5806 entries, 0 to 5805
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 5805 non-null   object
#  1   type                  5806 non-null   object
#  2   release_year          5806 non-null   int64
#  3   age_certification     3196 non-null   object
#  4   runtime               5806 non-null   int64
#  5   genres                5806 non-null   object
#  6   production_countries  5806 non-null   object
#  7   seasons               2047 non-null   float64
#  8   imdb_id               5362 non-null   object
#  9   imdb_score            5283 non-null   float64
#  10  imdb_votes            5267 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 499.1+ KB

# %% [markdown]
# Describe all numeric columns in the dataset.

# %%
movie_df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes
# count   5806.000000  5806.000000  2047.000000  5283.000000  5.267000e+03
# mean    2016.013434    77.643989     2.165608     6.533447  2.340719e+04
# std        7.324883    39.474160     2.636207     1.160932  8.713432e+04
# min     1945.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2015.000000    44.000000     1.000000     5.800000  5.210000e+02
# 50%     2018.000000    84.000000     1.000000     6.600000  2.279000e+03
# 75%     2020.000000   105.000000     2.000000     7.400000  1.014400e+04
# max     2022.000000   251.000000    42.000000     9.600000  2.268288e+06

# %% [markdown]
# Get the values which are stored in a column.

# %%
movie_df["production_countries"].unique()
# Out:
# array(["['US']", "['GB']", "['US', 'GB']", "['JP']", "['EG']", "['DE']",
#        "['IN']", '[]', "['DZ', 'EG']", "['LB']", "['FR', 'LB', 'CA']",
#        "['IN', 'SU']", "['US', 'IT']", "['HK', 'US']", "['GB', 'US']",
#        "['AR']", "['KW']", "['EG', 'FR']", "['FR', 'LB']", "['US', 'JP']",
#        "['US', 'CA']", "['DE', 'US']", "['US', 'DE']", "['CA', 'US']",
#        "['US', 'FR']", "['PE', 'US', 'BR']", "['IT', 'US', 'FR']",
#        "['US', 'HK']", "['FR', 'IE', 'GB', 'DE']",
#        "['GH', 'GB', 'US', 'BF', 'DE']", "['AR', 'ES']", "['FR']",
#        "['MX']", "['AU']", "['CO']", "['BE', 'FR', 'NO', 'LB']",
#        "['IT', 'LB', 'BE', 'FR']", "['US', 'FR', 'DE', 'PS']", "['TR']",
#        "['CA']", "['GB', 'US', 'BS', 'CZ', 'DE']", "['GB', 'US', 'AU']",
#        "['DE', 'ES', 'US', 'FR']", "['GB', 'US', 'AU', 'DE']",
#        "['JP', 'US']", "['US', 'IS', 'GB']", "['DK']",
#        "['NZ', 'JP', 'US']", "['US', 'CA', 'FR']", "['GB', 'US', 'DE']",
# ...

# %%
movie_df["type"].value_counts()
# Out:
# type
# MOVIE    3759
# SHOW     2047
# Name: count, dtype: int64

# %% [markdown]
# #### Add new column to the dataset

# %%
movie_df["runtime_and_ads"] = movie_df["runtime"] + 12
movie_df.head()
# Out:
#                                  title   type  release_year age_certification  \
# 0  Five Came Back: The Reference Films   SHOW          1945             TV-MA
# 1                          Taxi Driver  MOVIE          1976                 R
# 2      Monty Python and the Holy Grail  MOVIE          1975                PG
# 3                        Life of Brian  MOVIE          1979                 R
# 4                         The Exorcist  MOVIE          1973                 R
#
#    runtime                 genres production_countries  seasons    imdb_id  \
# 0       48      ['documentation']               ['US']      1.0        NaN
# 1      113     ['crime', 'drama']               ['US']      NaN  tt0075314
# 2       91  ['comedy', 'fantasy']               ['GB']      NaN  tt0071853
# 3       94             ['comedy']               ['GB']      NaN  tt0079470
# 4      133             ['horror']               ['US']      NaN  tt0070047
#
#    imdb_score  imdb_votes  runtime_and_ads
# ...

# %% [markdown]
# #### Filtering Dataframes

# %% [markdown]
# Get all new movies by filtering: movies released after 2014.

# %%
filtered_movie_df = movie_df[movie_df['release_year'] > 2014]
filtered_movie_df
# Out:
#                                    title   type  release_year  \
# 1217                    Better Call Saul   SHOW          2015
# 1218                    The Last Kingdom   SHOW          2015
# 1219                     Stranger Things   SHOW          2016
# 1220                      Schitt's Creek   SHOW          2015
# 1221                               Alone   SHOW          2015
# ...                                  ...    ...           ...
# 5801                           Fine Wine  MOVIE          2021
# 5802                      Edis Starlight  MOVIE          2021
# 5803                               Clash  MOVIE          2021
# 5804                      Shadow Parties  MOVIE          2021
# 5805  Mighty Little Bheem: Kite Festival   SHOW          2021
#
#      age_certification  runtime  \
# 1217             TV-MA       49
# 1218             TV-MA       55
# 1219             TV-14       52
# 1220             TV-14       22
# 1221             TV-MA       48
# ...

# %% [markdown]
# #### Sorting Dataframes

# %%
sorted_movie_df = movie_df.sort_values("release_year", ascending=True)
sorted_movie_df
# Out:
#                                     title   type  release_year  \
# 0     Five Came Back: The Reference Films   SHOW          1945
# 24                        Raya and Sakina  MOVIE          1953
# 28                        The Blazing Sun  MOVIE          1954
# 15                        White Christmas  MOVIE          1954
# 22                            Dark Waters  MOVIE          1956
# ...                                   ...    ...           ...
# 5096              Ronny Chieng: Speakeasy  MOVIE          2022
# 5511              Mike Epps: Indiana Mike  MOVIE          2022
# 5654                        Into the Wind  MOVIE          2022
# 5225                          Tall Girl 2  MOVIE          2022
# 5284               Etharkkum Thunindhavan  MOVIE          2022
#
#      age_certification  runtime                                      genres  \
# 0                TV-MA       48                           ['documentation']
# ...

# %% [markdown]
# ## Tasks

# %% [markdown]
# **Task: 1** replace NaN in column "seasons" with 0

# %%
# your code

# %% [markdown]
# **Task: 2** drop column "imdb_id"

# %%
# your code

# %% [markdown]
# **Task: 3** replace [] in column "production_countries" with NaN

# %%
# your code

# %% [markdown]
# **Task: 4** get the movie / show with the most "imdb_votes"

# %%
# your code

# %% [markdown]
# **Bonus Task: 5** replace all "age_certification" with numbers. **Hint** there is a function called "map" in pandas, if there is a NaN map it as 18 (not in the mapping dictionary)

# %%
movie_df["age_certification"].unique()
# Out:
# array(['TV-MA', 'R', 'PG', 'TV-14', 'G', 'PG-13', nan, 'TV-PG', 'TV-Y',
#        'TV-G', 'TV-Y7', 'NC-17'], dtype=object)

# %%
age_mapping = {
    'TV-MA': 17,
    'R': 17,
    'PG': 13,
    'TV-14': 14,
    'G': 0,
    'PG-13': 13,
    'TV-PG': 13,
    'TV-Y': 0,
    'TV-G': 0,
    'TV-Y7': 7,
    'NC-17': 17
}

# %%
# your code

# %% [markdown]
# **Task: 6** save the dataframe as a csv file named "imdb_movies_shows_cleaned.csv"

# %%
# your code
